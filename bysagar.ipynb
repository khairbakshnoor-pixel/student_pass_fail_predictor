# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={
    'Name':['Babar','kholi','Rohit',"Rizwan"],
    'Age':[None,39,38,None],
    'Runs':[10000,20000,None,None]
}

# %%
df=pd.DataFrame(data
                )

# %%
df
# Out:
#      Name   Age     Runs
# 0   Babar   NaN  10000.0
# 1   kholi  39.0  20000.0
# 2   Rohit  38.0      NaN
# 3  Rizwan   NaN      NaN

# %%
df.isnull().sum()
# Out:
# Name    0
# Age     2
# Runs    2
# dtype: int64

# %%
df['Age']=df['Age'].fillna(df['Age'].mean(),inplace=True)
# Out:
# C:\Users\khair bakhsh\AppData\Local\Temp\ipykernel_13888\3291053296.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Age']=df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df
# Out:
#      Name   Age     Runs
# 0   Babar  38.5  10000.0
# 1   kholi  39.0  20000.0
# 2   Rohit  38.0      NaN
# 3  Rizwan  38.5      NaN

# %%
df['Runs']=df['Runs'].fillna(df['Runs'].mean(),inplace=True)
# Out:
# C:\Users\khair bakhsh\AppData\Local\Temp\ipykernel_13888\817067196.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Runs']=df['Runs'].fillna(df['Runs'].mean(),inplace=True)

# %%
df
# Out:
#      Name   Age     Runs
# 0   Babar  38.5  10000.0
# 1   kholi  39.0  20000.0
# 2   Rohit  38.0  15000.0
# 3  Rizwan  38.5  15000.0

# %%
from sklearn.preprocessing import LabelEncoder


df=pd.read_csv('Employee Dataset - AR1.csv')
df2=df.copy()
le=LabelEncoder()
df2['is_male']=le.fit_transform(df2['Gender'])
df2['status']=le.fit_transform(df2['Marital Status'])

# %%
df2['is_male']
# Out:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    1
# 5    1
# 6    0
# 7    1
# Name: is_male, dtype: int64

# %%
df2
# Out:
#   Employee Name  Age Last Working Day            Department      Education  \
# 0        Jitesh   41       31-12-9999              Training        Masters
# 1        Sanjit   49       31-12-9999                 Sales        Masters
# 2          John   37       31-12-9999                   R&D      Doctorate
# 3        Sandra   33       31-12-9999  Software Development  Undergraduate
# 4         Madhu   27       31-12-9999                   R&D        Masters
# 5        Robert   32       31-12-9999                   R&D        Masters
# 6         Megan   59       31-12-9999  Software Development        Masters
# 7          Matt   30       31-12-9999                   R&D      Doctorate
#
#    Gender Marital Status  Monthly Income  Years of Experience  \
# 0    Male         Single            5993                    8
# 1    Male        Married            5130                    1
# 2    Male         Single            2090                    6
# ...

# %%
df_onehot = pd.get_dummies(df2, columns=['Education'],dtype='int')

# %%
df_onehot
# Out:
#   Employee Name  Age Last Working Day            Department  Gender  \
# 0        Jitesh   41       31-12-9999              Training    Male
# 1        Sanjit   49       31-12-9999                 Sales    Male
# 2          John   37       31-12-9999                   R&D    Male
# 3        Sandra   33       31-12-9999  Software Development  Female
# 4         Madhu   27       31-12-9999                   R&D    Male
# 5        Robert   32       31-12-9999                   R&D    Male
# 6         Megan   59       31-12-9999  Software Development  Female
# 7          Matt   30       31-12-9999                   R&D    Male
#
#   Marital Status  Monthly Income  Years of Experience  Percent Salary Hike  \
# 0         Single            5993                    8                   11
# 1        Married            5130                    1                   23
# 2         Single            2090                    6                   15
# ...

# %%
from sklearn.metrics import confusion_matrix
y_true=[1,0,0,1,0,0,1,1,0]
y_pred=[0,1,1,0,1,0,0,1,0]
cm=confusion_matrix(y_true,y_pred)
cm
# Out:
# array([[2, 3],
#        [3, 1]])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
import numpy as np
real_score=[80,90,70,100,80]
predicted_score=[70,80,95,96,90]
mae=mean_absolute_error(real_score,predicted_score)
mse=mean_squared_error(real_score,predicted_score)
rmse=np.sqrt(mse)
mae
# Out:
# 11.8

# %%
mse
# Out:
# 188.2

# %%
rmse
# Out:
# np.float64(13.718600511714014)
