# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("customer_churn_raw.csv")

# %%
df
# Out:
#     customer_id   age  gender        city  income signup_date     last_login  \
# 0          1001  25.0    Male     Karachi   55000  2023-01-12     2024-02-10
# 1          1002  31.0  Female      Lahore   72000  12/03/2023     2024-02-01
# 2          1003   NaN    Male   Islamabad   68000  2023/02/01     2024-01-28
# 3          1004  22.0       F     Karachi       ?  2023-05-20     2024-02-14
# 4          1005  45.0    Male     Karachi  150000  2022-11-02     2023-12-25
# 5          1006  29.0  female      Lahore   64000  2023-06-10     2024-01-05
# 6          1007  52.0    Male   Islamabad  -20000  2023-04-15     2024-02-11
# 7          1008  38.0  Female     Karachi   82000  2023-02-28  not_available
# 8          1009  27.0    Male    Karachi    59000  2023-01-18     2024-02-12
# 9          1010  19.0  Female      Lahore   32000  2023-08-01     2024-02-15
# 10         1011  61.0    Male   Islamabad  200000  2022-10-10     2024-02-10
# 11         1012  34.0  Female     Karachi   71000  2023-03-09     2024-02-05
# 12         1013  28.0    Male      Lahore   63000  2023-02-14     2024-01-30
# 13         1014  40.0  Female     Karachi   90000  2023-04-20     2024-01-18
# 14         1015  23.0    Male   Islamabad   48000  2023-07-12     2024-01-29
# 15         1016  36.0  Female      Lahore   77000  2023-06-02     2024-02-02
# 16         1017  55.0    Male     Karachi  160000  2022-09-21     2024-02-11
# 17         1018  33.0  Female      Lahore   69000  2023-05-11     2024-01-15
# 18         1019   NaN    Male     Karachi   60000  2023-01-25     2024-02-13
# 19         1020  26.0  Female   Islamabad   54000  2023-02-02     2024-02-12
# 20         1021  41.0    Male     Karachi   88000  2023-03-30     2024-01-27
# 21         1022  30.0  Female      Lahore   71000  2023-05-14     2024-01-19
# 22         1023  48.0    Male     Karachi  125000  2022-12-01     2024-02-14
# 23         1024  21.0  Female   Islamabad   35000  2023-08-20     2024-02-13
# 24         1025  39.0    Male      Lahore   82000  2023-04-09     2024-01-22
# 25         1026  42.0  Female     Karachi   91000  2023-02-18     2024-02-01
# 26         1027  24.0    Male      Lahore   52000  2023-07-01     2024-02-09
# 27         1028  60.0  Female   Islamabad  180000  2022-08-10     2024-02-12
# 28         1029  37.0    Male     Karachi   79000  2023-05-25     2024-01-26
# 29         1030  28.0  Female      Lahore   61000  2023-03-05     2024-01-30
# 30         1031  44.0    Male     Karachi  102000  2023-02-11     2024-02-15
# 31         1032  20.0  Female   Islamabad   30000  2023-09-01     2024-02-16
# 32         1033  47.0    Male      Lahore  118000  2022-11-15     2024-02-10
# 33         1034  29.0  Female     Karachi   67000  2023-06-18     2024-02-06
# 34         1035  53.0    Male   Islamabad  140000  2022-10-05     2024-01-28
# 35         1036  35.0  Female      Lahore   76000  2023-03-21     2024-01-24
# 36         1037  31.0    Male     Karachi   69000  2023-04-12     2024-01-29
# 37         1038  27.0  Female      Lahore   58000  2023-07-22     2024-02-03
# 38         1039  50.0    Male   Islamabad  135000  2022-12-20     2024-02-12
# 39         1040  34.0  Female     Karachi   72000  2023-01-30     2024-02-07
# 40         1001  25.0    Male     Karachi   55000  2023-01-12     2024-02-10
#
#         plan  monthly_usage_gb  support_tickets  churned                notes
# 0    Premium               120                1        0        Good customer
# 1      Basic                45                3        1           late payer
# 2   standard                60                2        0                  NaN
# 3      Basic                15                5        1  Too many complaints
# 4    Premium               350                0        0                  VIP
# 5   Standard                75                2        0                  NaN
# 6      Basic                30                7        1            Bad data?
# 7    Premium                95                1        0                  NaN
# 8      Basic                40                2        1                  NaN
# 9      Basic                10                6        1             new user
# 10   Premium               400                0        0            Old loyal
# 11  Standard                70                3        0                  NaN
# 12  standard                65                2        0                  NaN
# 13   Premium               110                1        0                  NaN
# 14     Basic                25                4        1                  NaN
# 15  Standard                80                1        0                  NaN
# 16   Premium               300                0        0                  NaN
# 17     Basic                50                3        1                  NaN
# 18     Basic                35                2        1                  NaN
# 19  Standard                58                2        0                  NaN
# 20   Premium               105                1        0                  NaN
# 21     Basic                42                4        1                  NaN
# 22   Premium               210                0        0                  NaN
# 23     Basic                12                6        1                  NaN
# 24  Standard                85                1        0                  NaN
# 25   Premium               115                1        0                  NaN
# 26     Basic                28                3        1                  NaN
# 27   Premium               320                0        0                  NaN
# 28  Standard                78                2        0                  NaN
# 29     Basic                40                3        1                  NaN
# 30   Premium               130                0        0                  NaN
# 31     Basic                 9                7        1                  NaN
# 32   Premium               200                0        0                  NaN
# 33  Standard                72                2        0                  NaN
# 34   Premium               250                1        0                  NaN
# 35     Basic                55                3        1                  NaN
# 36  Standard                67                2        0                  NaN
# 37     Basic                30                4        1                  NaN
# 38   Premium               240                0        0                  NaN
# 39  Standard                74                2        0                  NaN
# 40   Premium               120                1        0        duplicate_row

# %%
df.shape
# Out:
# (41, 12)

# %%
df.isnull().sum()
# Out:
# customer_id          0
# age                  2
# gender               0
# city                 0
# income               0
# signup_date          0
# last_login           0
# plan                 0
# monthly_usage_gb     0
# support_tickets      0
# churned              0
# notes               33
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       41 non-null     int64
#  1   age               39 non-null     float64
#  2   gender            41 non-null     str
#  3   city              41 non-null     str
#  4   income            41 non-null     str
#  5   signup_date       41 non-null     str
#  6   last_login        41 non-null     str
#  7   plan              41 non-null     str
#  8   monthly_usage_gb  41 non-null     int64
#  9   support_tickets   41 non-null     int64
#  10  churned           41 non-null     int64
#  11  notes             8 non-null      str
# dtypes: float64(1), int64(4), str(7)
# memory usage: 4.0 KB

# %%
df['income']=pd.to_numeric(df['income'],errors='coerce')

# %%
df['signup_date']=pd.to_datetime(df['signup_date'],errors='coerce')
df['last_login']=pd.to_datetime(df['last_login'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       41 non-null     int64
#  1   age               39 non-null     float64
#  2   gender            41 non-null     str
#  3   city              41 non-null     str
#  4   income            40 non-null     float64
#  5   signup_date       39 non-null     datetime64[us]
#  6   last_login        40 non-null     datetime64[us]
#  7   plan              41 non-null     str
#  8   monthly_usage_gb  41 non-null     int64
#  9   support_tickets   41 non-null     int64
#  10  churned           41 non-null     int64
#  11  notes             8 non-null      str
# dtypes: datetime64[us](2), float64(2), int64(4), str(4)
# memory usage: 4.0 KB

# %%
df['age']=df['age'].fillna(df['age'].median())

# %%
df.head()
# Out:
#    customer_id   age  gender       city    income signup_date last_login  \
# 0         1001  25.0    Male    Karachi   55000.0  2023-01-12 2024-02-10
# 1         1002  31.0  Female     Lahore   72000.0         NaT 2024-02-01
# 2         1003  34.0    Male  Islamabad   68000.0         NaT 2024-01-28
# 3         1004  22.0       F    Karachi       NaN  2023-05-20 2024-02-14
# 4         1005  45.0    Male    Karachi  150000.0  2022-11-02 2023-12-25
#
#        plan  monthly_usage_gb  support_tickets  churned                notes
# 0   Premium               120                1        0        Good customer
# 1     Basic                45                3        1           late payer
# 2  standard                60                2        0                  NaN
# 3     Basic                15                5        1  Too many complaints
# 4   Premium               350                0        0                  VIP

# %%
df['notes']=df['notes'].fillna('no comments')

# %%
df.isnull().sum()
# Out:
# customer_id         0
# age                 0
# gender              0
# city                0
# income              1
# signup_date         2
# last_login          1
# plan                0
# monthly_usage_gb    0
# support_tickets     0
# churned             0
# notes               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#after cleaning anylayez the data 
#brek into 4 gorups
#numerical numeriacal
#numerical categorial
#categorial categorial
#date time

# %%
df["churned"].value_counts()
# Out:
# churned
# 0    26
# 1    15
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        customer_id        age         income                 signup_date  \
# count    41.000000  41.000000      40.000000                          39
# mean   1020.024390  35.536585   81000.000000  2023-03-12 08:36:55.384615
# min    1001.000000  19.000000  -20000.000000         2022-08-10 00:00:00
# 25%    1010.000000  27.000000   58750.000000         2023-01-15 00:00:00
# 50%    1020.000000  34.000000   71000.000000         2023-03-09 00:00:00
# 75%    1030.000000  42.000000   90250.000000         2023-05-22 12:00:00
# max    1040.000000  61.000000  200000.000000         2023-09-01 00:00:00
# std      11.938358  11.086247   42425.198124                         NaN
#
#                 last_login  monthly_usage_gb  support_tickets    churned
# count                   40         41.000000        41.000000  41.000000
# mean   2024-02-02 13:48:00        105.243902         2.195122   0.365854
# min    2023-12-25 00:00:00          9.000000         0.000000   0.000000
# 25%    2024-01-28 00:00:00         40.000000         1.000000   0.000000
# 50%    2024-02-05 12:00:00         72.000000         2.000000   0.000000
# 75%    2024-02-12 00:00:00        120.000000         3.000000   1.000000
# max    2024-02-16 00:00:00        400.000000         7.000000   1.000000
# std                    NaN         98.756969         1.926389   0.487652

# %%
#most important step total anylyze the data
df.hist(figsize=(15,15))
plt.show()

# %%
#removing outliers
df = df[df["income"] > 0]

# %%
#LOOK FOR OUTLIERS
x=df['income'].value_counts()
sns.boxplot(df['income'])
plt.show()

# %%
#Numerical vs Target
df.groupby("churned")["income"].mean()
# Out:
# churned
# 0    97576.923077
# 1    55615.384615
# Name: income, dtype: float64

# %%
df.groupby("churned")["monthly_usage_gb"].mean()
# Out:
# churned
# 0    148.038462
# 1     32.384615
# Name: monthly_usage_gb, dtype: float64

# %%
df.groupby("churned")["support_tickets"].mean()
# Out:
# churned
# 0    1.076923
# 1    3.846154
# Name: support_tickets, dtype: float64

# %%
# Red tones → positive correlation

# Blue tones → negative correlation

# White/light colors → near zero correlation

sns.heatmap(df.corr(numeric_only=True), cmap="coolwarm",annot=True)
plt.show()

# %%
df.head()
# Out:
#    customer_id   age  gender       city    income signup_date last_login  \
# 0         1001  25.0    Male    Karachi   55000.0  2023-01-12 2024-02-10
# 1         1002  31.0  Female     Lahore   72000.0         NaT 2024-02-01
# 2         1003  34.0    Male  Islamabad   68000.0         NaT 2024-01-28
# 4         1005  45.0    Male    Karachi  150000.0  2022-11-02 2023-12-25
# 5         1006  29.0  female     Lahore   64000.0  2023-06-10 2024-01-05
#
#        plan  monthly_usage_gb  support_tickets  churned          notes
# 0   Premium               120                1        0  Good customer
# 1     Basic                45                3        1     late payer
# 2  standard                60                2        0    no comments
# 4   Premium               350                0        0            VIP
# 5  Standard                75                2        0    no comments

# %%
df2 = df.drop(columns=['notes'])

# %%
from sklearn.preprocessing import LabelEncoder
df=pd.read_csv("customer_churn_raw.csv")
df2=df.copy()
le=LabelEncoder()
df2['plan']=le.fit_transform(df2['plan'])

# %%
df2['gender']=le.fit_transform(df2['gender'])

# %%
df2['age']=df2['age'].fillna('other')

# %%
df2.isnull().sum()
# Out:
# customer_id          0
# age                  0
# gender               0
# city                 0
# income               0
# signup_date          0
# last_login           0
# plan                 0
# monthly_usage_gb     0
# support_tickets      0
# churned              0
# notes               33
# dtype: int64

# %%
df2.head()
# Out:
#    customer_id    age  gender       city  income signup_date  last_login  \
# 0         1001   25.0       2    Karachi   55000  2023-01-12  2024-02-10
# 1         1002   31.0       1     Lahore   72000  12/03/2023  2024-02-01
# 2         1003  other       2  Islamabad   68000  2023/02/01  2024-01-28
# 3         1004   22.0       0    Karachi       ?  2023-05-20  2024-02-14
# 4         1005   45.0       2    Karachi  150000  2022-11-02  2023-12-25
#
#    plan  monthly_usage_gb  support_tickets  churned                notes
# 0     1               120                1        0        Good customer
# 1     0                45                3        1           late payer
# 2     3                60                2        0                  NaN
# 3     0                15                5        1  Too many complaints
# 4     1               350                0        0                  VIP

# %%
one_hot=pd.get_dummies(df2,columns=['city'],prefix='city',dtype=int)

# %%
one_hot
# Out:
#     customer_id    age  gender  income signup_date     last_login  plan  \
# 0          1001   25.0       2   55000  2023-01-12     2024-02-10     1
# 1          1002   31.0       1   72000  12/03/2023     2024-02-01     0
# 2          1003  other       2   68000  2023/02/01     2024-01-28     3
# 3          1004   22.0       0       ?  2023-05-20     2024-02-14     0
# 4          1005   45.0       2  150000  2022-11-02     2023-12-25     1
# 5          1006   29.0       3   64000  2023-06-10     2024-01-05     2
# 6          1007   52.0       2  -20000  2023-04-15     2024-02-11     0
# 7          1008   38.0       1   82000  2023-02-28  not_available     1
# 8          1009   27.0       2   59000  2023-01-18     2024-02-12     0
# 9          1010   19.0       1   32000  2023-08-01     2024-02-15     0
# 10         1011   61.0       2  200000  2022-10-10     2024-02-10     1
# 11         1012   34.0       1   71000  2023-03-09     2024-02-05     2
# 12         1013   28.0       2   63000  2023-02-14     2024-01-30     3
# 13         1014   40.0       1   90000  2023-04-20     2024-01-18     1
# 14         1015   23.0       2   48000  2023-07-12     2024-01-29     0
# 15         1016   36.0       1   77000  2023-06-02     2024-02-02     2
# 16         1017   55.0       2  160000  2022-09-21     2024-02-11     1
# 17         1018   33.0       1   69000  2023-05-11     2024-01-15     0
# 18         1019  other       2   60000  2023-01-25     2024-02-13     0
# 19         1020   26.0       1   54000  2023-02-02     2024-02-12     2
# 20         1021   41.0       2   88000  2023-03-30     2024-01-27     1
# 21         1022   30.0       1   71000  2023-05-14     2024-01-19     0
# 22         1023   48.0       2  125000  2022-12-01     2024-02-14     1
# 23         1024   21.0       1   35000  2023-08-20     2024-02-13     0
# 24         1025   39.0       2   82000  2023-04-09     2024-01-22     2
# 25         1026   42.0       1   91000  2023-02-18     2024-02-01     1
# 26         1027   24.0       2   52000  2023-07-01     2024-02-09     0
# 27         1028   60.0       1  180000  2022-08-10     2024-02-12     1
# 28         1029   37.0       2   79000  2023-05-25     2024-01-26     2
# 29         1030   28.0       1   61000  2023-03-05     2024-01-30     0
# 30         1031   44.0       2  102000  2023-02-11     2024-02-15     1
# 31         1032   20.0       1   30000  2023-09-01     2024-02-16     0
# 32         1033   47.0       2  118000  2022-11-15     2024-02-10     1
# 33         1034   29.0       1   67000  2023-06-18     2024-02-06     2
# 34         1035   53.0       2  140000  2022-10-05     2024-01-28     1
# 35         1036   35.0       1   76000  2023-03-21     2024-01-24     0
# 36         1037   31.0       2   69000  2023-04-12     2024-01-29     2
# 37         1038   27.0       1   58000  2023-07-22     2024-02-03     0
# 38         1039   50.0       2  135000  2022-12-20     2024-02-12     1
# 39         1040   34.0       1   72000  2023-01-30     2024-02-07     2
# 40         1001   25.0       2   55000  2023-01-12     2024-02-10     1
#
#     monthly_usage_gb  support_tickets  churned                notes  \
# 0                120                1        0        Good customer
# 1                 45                3        1           late payer
# 2                 60                2        0                  NaN
# 3                 15                5        1  Too many complaints
# 4                350                0        0                  VIP
# 5                 75                2        0                  NaN
# 6                 30                7        1            Bad data?
# 7                 95                1        0                  NaN
# 8                 40                2        1                  NaN
# 9                 10                6        1             new user
# 10               400                0        0            Old loyal
# 11                70                3        0                  NaN
# 12                65                2        0                  NaN
# 13               110                1        0                  NaN
# 14                25                4        1                  NaN
# 15                80                1        0                  NaN
# 16               300                0        0                  NaN
# 17                50                3        1                  NaN
# 18                35                2        1                  NaN
# 19                58                2        0                  NaN
# 20               105                1        0                  NaN
# 21                42                4        1                  NaN
# 22               210                0        0                  NaN
# 23                12                6        1                  NaN
# 24                85                1        0                  NaN
# 25               115                1        0                  NaN
# 26                28                3        1                  NaN
# 27               320                0        0                  NaN
# 28                78                2        0                  NaN
# 29                40                3        1                  NaN
# 30               130                0        0                  NaN
# 31                 9                7        1                  NaN
# 32               200                0        0                  NaN
# 33                72                2        0                  NaN
# 34               250                1        0                  NaN
# 35                55                3        1                  NaN
# 36                67                2        0                  NaN
# 37                30                4        1                  NaN
# 38               240                0        0                  NaN
# 39                74                2        0                  NaN
# 40               120                1        0        duplicate_row
#
#     city_  Karachi   city_Islamabad  city_Karachi  city_Lahore
# 0                 0               0             1            0
# 1                 0               0             0            1
# 2                 0               1             0            0
# 3                 0               0             1            0
# 4                 0               0             1            0
# 5                 0               0             0            1
# 6                 0               1             0            0
# 7                 0               0             1            0
# 8                 1               0             0            0
# 9                 0               0             0            1
# 10                0               1             0            0
# 11                0               0             1            0
# 12                0               0             0            1
# 13                0               0             1            0
# 14                0               1             0            0
# 15                0               0             0            1
# 16                0               0             1            0
# 17                0               0             0            1
# 18                0               0             1            0
# 19                0               1             0            0
# 20                0               0             1            0
# 21                0               0             0            1
# 22                0               0             1            0
# 23                0               1             0            0
# 24                0               0             0            1
# 25                0               0             1            0
# 26                0               0             0            1
# 27                0               1             0            0
# 28                0               0             1            0
# 29                0               0             0            1
# 30                0               0             1            0
# 31                0               1             0            0
# 32                0               0             0            1
# 33                0               0             1            0
# 34                0               1             0            0
# 35                0               0             0            1
# 36                0               0             1            0
# 37                0               0             0            1
# 38                0               1             0            0
# 39                0               0             1            0
# 40                0               0             1            0
